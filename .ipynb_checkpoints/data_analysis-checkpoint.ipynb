# %% [markdown]
# # General overview

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from flatten_json import flatten
pd.set_option('display.max_columns', 50)

# %%
df = pd.read_json("planning.json")

# %%
with open("planning.json", "rb") as f:
    data = json.load(f)

# %% [markdown]
# As there are multiple nested lists in the JSON data, flattening is necessary. As both nested lists have the same keys, I need to apply the prefix to keep track of what category it comes from. I drop the columns requiredSkills and optionalSkills as they are already flattened.

# %%
flattened = (flatten(d, '.') for d in data)
df_flattened = pd.DataFrame(flattened).drop(['requiredSkills', 'optionalSkills'], axis=1)

# %%
df_flattened
# Out:
#          id originalId  talentId                  talentName     talentGrade  \
# 0         1   62d396e7  tln_3084    Frau Hermine Caspar MBA.          Intern
# 1         2   3d857160
# 2         3   fd630e1f  tln_9166         Annegrete Eberhardt  Senior Manager
# 3         4   63349369  tln_3790  Francesca Mülichen-Jungfer  Lead Associate
# 4         5   25fded26  tln_3790  Francesca Mülichen-Jungfer  Lead Associate
# ...     ...        ...       ...                         ...             ...
# 9995   9996   bbaa10a3  tln_7350              Martina Dippel         Manager
# 9996   9997   45500dca  tln_7793  Arnim Barkholz-Austermühle          Intern
# 9997   9998   55361b66
# 9998   9999   a90fecb2
# 9999  10000   fd5b4f18
#
#         bookingGrade      operatingUnit  officeCity officePostalCode  \
# 0                      Operating Unit 3     Hamburg            97311
# 1     Lead Associate  Operating Unit 10       Forst            50777
# 2                      Operating Unit 5      Jessen            23887
# 3                      Operating Unit 4     Wolfach            62545
# 4                      Operating Unit 7    Iserlohn            01215
# ...              ...                ...         ...              ...
# 9995                   Operating Unit 8   Altötting            42828
# 9996                   Operating Unit 6    Rochlitz            93218
# 9997       Associate   Operating Unit 9  Ravensburg            96235
# 9998  Senior Manager   Operating Unit 3   Saarlouis            23579
# 9999       Associate   Operating Unit 7      Meißen            53443
#
#                    jobManagerName jobManagerId  totalHours  \
# 0                    Marjan Hande     tln_3019        33.0
# 1          Herr Remo Radisch MBA.     tln_4722        33.0
# 2             Hans-Eberhard Hövel     tln_8405        33.0
# 3                  Theobald Krebs     tln_3592        23.0
# 4             Kazim Becker B.Eng.     tln_7074        23.0
# ...                           ...          ...         ...
# 9995               Ullrich Renner     tln_9067        32.0
# 9996                Gunda Carsten     tln_9112        36.0
# 9997  Dipl.-Ing. Bianca Rust MBA.     tln_7613        26.0
# 9998          Prof. Yasemin Hänel     tln_5069        29.0
# 9999               Sergej Matthäi     tln_9782        25.0
#
#                 startDate              endDate clientName clientId  \
# 0     11/01/2022 04:42 PM  11/05/2022 07:42 PM       Döhn     cl_1
# 1     03/08/2022 02:24 PM  03/12/2022 05:24 PM       Döhn     cl_1
# 2     06/14/2022 03:00 AM  06/18/2022 06:00 AM       Döhn     cl_1
# 3     02/25/2022 07:25 PM  02/28/2022 04:25 PM       Döhn     cl_1
# 4     01/26/2022 10:06 AM  01/29/2022 07:06 AM       Döhn     cl_1
# ...                   ...                  ...        ...      ...
# 9995  09/24/2022 07:50 PM  09/28/2022 07:50 PM       Rust   cl_100
# 9996  12/23/2022 11:35 AM  12/27/2022 11:35 PM       Rust   cl_100
# 9997  06/05/2022 08:29 AM  06/08/2022 02:29 PM       Rust   cl_100
# 9998  11/21/2022 05:23 AM  11/24/2022 08:23 PM       Rust   cl_100
# 9999  05/26/2022 12:12 AM  05/29/2022 03:12 AM       Rust   cl_100
#
#             industry  isUnassigned requiredSkills.0.name  \
# 0     Low technology         False                   NaN
# 1     Low technology          True                German
# 2     Low technology         False                Python
# 3     Low technology         False                French
# 4     Low technology         False            Javascript
# ...              ...           ...                   ...
# 9995            Film         False            TypeScript
# 9996            Film         False               English
# 9997            Film          True                     R
# 9998            Film          True                Python
# 9999            Film          True                   NaN
#
#      requiredSkills.0.category requiredSkills.1.name  \
# 0                          NaN                   NaN
# 1                     Language            Javascript
# 2              Coding Language                German
# 3                     Language            TypeScript
# 4              Coding Language                French
# ...                        ...                   ...
# 9995           Coding Language                   NaN
# 9996                  Language                German
# 9997           Coding Language                   NaN
# 9998           Coding Language            Javascript
# 9999                       NaN                   NaN
#
#      requiredSkills.1.category requiredSkills.2.name  \
# 0                          NaN                   NaN
# 1              Coding Language               English
# 2                     Language                     R
# 3              Coding Language               English
# 4                     Language               English
# ...                        ...                   ...
# 9995                       NaN                   NaN
# 9996                  Language            Javascript
# 9997                       NaN                   NaN
# 9998           Coding Language                French
# 9999                       NaN                   NaN
#
#      requiredSkills.2.category optionalSkills.0.name  \
# 0                          NaN                   NaN
# 1                     Language            TypeScript
# 2              Coding Language                French
# 3                     Language                 React
# 4                     Language                     R
# ...                        ...                   ...
# 9995                       NaN                   C++
# 9996           Coding Language                   C++
# 9997                       NaN               English
# 9998                  Language                 Scala
# 9999                       NaN                     R
#
#      optionalSkills.0.category requiredSkills.3.name requiredSkills.3.category
# 0                          NaN                   NaN                       NaN
# 1              Coding Language                   NaN                       NaN
# 2                     Language                   NaN                       NaN
# 3              Coding Language            Javascript           Coding Language
# 4              Coding Language                   NaN                       NaN
# ...                        ...                   ...                       ...
# 9995           Coding Language                   NaN                       NaN
# 9996           Coding Language                French                  Language
# 9997                  Language                   NaN                       NaN
# 9998           Coding Language                German                  Language
# 9999           Coding Language                   NaN                       NaN
#
# [10000 rows x 28 columns]

# %%
df.dtypes
# Out:
# id                   int64
# originalId          object
# talentId            object
# talentName          object
# talentGrade         object
# bookingGrade        object
# operatingUnit       object
# officeCity          object
# officePostalCode     int64
# jobManagerName      object
# jobManagerId        object
# totalHours           int64
# startDate           object
# endDate             object
# clientName          object
# clientId            object
# industry            object
# isUnassigned          bool
# requiredSkills      object
# optionalSkills      object
# dtype: object

# %% [markdown]
# Number of entries in the data: 10,000.
#
# ### Data model:
# - id: integer (unique, required) - ID of the project
# - originalId: string (unique, required) - ID of the project
# - talentId: string (optional) - ID of the talent working on the project
# - talentName: string (optional) - Name of the talent working on the project
# - talentGrade: string (optional) - Grade of the talent working on the project
# - bookingGrade: string (optional) - Needed grade for a talent to be assigned on the project
# - operatingUnit: string (required) - Operating unit of the project
# - officeCity: string (optional) - Office city of the project
# - officePostalCode: string (required) - Postal code of the project
# - jobManagerName: string (optional) - Name of the manager of the project
# - jobManagerId: string (required) - ID of the manager of the project
# - totalHours: float (required) - Total hours for the project
# - startDate: string (required) - Start date of the project
# - endDate: string (required) - End date of the project
# - clientName: string (optional) - Name of the client
# - clientId: string (required) - ID of the client
# - industry: string (optional) - Industry of the project
# - isUnassigned: boolean (optional) - Is the project already assigned to a talent?
# - requiredSkills: array of key-value pair (optional) - can have up to 4 elements
# - optionalSkills: array of key-value pair (optional) - can have up to 1 element

# %%
df_flattened.nunique()
# Out:
# id                           10000
# originalId                   10000
# talentId                       719
# talentName                     719
# talentGrade                      7
# bookingGrade                     7
# operatingUnit                   10
# officeCity                     363
# officePostalCode               996
# jobManagerName                6308
# jobManagerId                  6316
# totalHours                      33
# startDate                     9900
# endDate                       9897
# clientName                     100
# clientId                       100
# industry                        47
# isUnassigned                     2
# requiredSkills.0.name           11
# requiredSkills.0.category        2
# requiredSkills.1.name           11
# requiredSkills.1.category        2
# requiredSkills.2.name           11
# requiredSkills.2.category        2
# optionalSkills.0.name           11
# optionalSkills.0.category        2
# requiredSkills.3.name           11
# requiredSkills.3.category        2
# dtype: int64

# %% [markdown]
# The company has 6316 managers and 10 operating units in 996 offices. The company has 100 clients specialised in 47 industries (one client has only one specialisation) and is working on 10,000 projects (100 projects per client). 2,030 projects have no talent assigned. When this is the case, the booking grade tells the grade that a talent needs to be assigned on this project. A talent or manager may be assigned to projects in different office cities or operating units.

# %% [markdown]
# # In-depth statistics

# %% [markdown]
# ### Investigating Industries

# %%
df_industry = df_flattened.groupby('industry')

# %%
df_industry.nunique()
# Out:
#                         id  originalId  talentId  talentName  talentGrade  \
# industry
# Advertising            100         100         6           6            5
# Arms                   100         100         8           8            6
# Automotive             100         100        10          10            6
# Broadcasting           300         300        23          23            7
# Chemical               100         100         7           7            5
# Computer               100         100         9           9            6
# Construction           100         100         8           8            5
# Creative               200         200        15          15            6
# Cultural               200         200        13          13            7
# Culture                200         200        17          17            7
# Defense                200         200        21          21            6
# Education              300         300        28          28            7
# Electric power         200         200        15          15            7
# Electronics            100         100         7           7            6
# Energy                 200         200        16          16            7
# Entertainment          200         200        15          15            7
# Fashion                300         300        23          23            7
# Film                   400         400        33          33            7
# Financial services     100         100        11          11            6
# Floral                 400         400        29          29            7
# Food                   300         300        26          26            7
# Information            300         300        24          24            7
# Insurance              100         100        10          10            6
# Internet               100         100        10          10            6
# Leisure                400         400        36          36            7
# Low technology         300         300        21          21            7
# Mass media             200         200        14          14            7
# Meat                   100         100         6           6            5
# Meat packing           100         100        10          10            6
# Mining                 100         100         8           8            4
# Music                  400         400        30          30            7
# News media             200         200        16          16            7
# Professional services  200         200        17          17            5
# Publishing             400         400        32          32            7
# Pulp and paper         300         300        23          23            7
# Real estate            300         300        23          23            7
# Retail                 100         100         6           6            5
# Semiconductor          200         200        17          17            6
# Services               300         300        21          21            7
# Shipbuilding           100         100         8           8            5
# Sport                  300         300        19          19            7
# Steel                  300         300        20          20            7
# Telecommunications     200         200        15          15            7
# Textile                400         400        31          31            6
# Transport              100         100         9           9            6
# Video game             200         200        16          16            7
# Water                  100         100         7           7            5
#
#                        bookingGrade  operatingUnit  officeCity  \
# industry
# Advertising                       7             10          81
# Arms                              6             10          82
# Automotive                        7             10          87
# Broadcasting                      7             10         178
# Chemical                          7             10          90
# Computer                          6             10          77
# Construction                      7             10          90
# Creative                          7             10         141
# Cultural                          7             10         149
# Culture                           7             10         145
# Defense                           7             10         151
# Education                         7             10         184
# Electric power                    7             10         144
# Electronics                       7             10          83
# Energy                            7             10         143
# Entertainment                     7             10         143
# Fashion                           7             10         188
# Film                              7             10         228
# Financial services                7             10          81
# Floral                            7             10         226
# Food                              7             10         201
# Information                       7             10         183
# Insurance                         7             10          88
# Internet                          7             10          85
# Leisure                           7             10         222
# Low technology                    7             10         178
# Mass media                        7             10         142
# Meat                              7             10          85
# Meat packing                      7             10          84
# Mining                            7             10          75
# Music                             7             10         224
# News media                        7             10         144
# Professional services             7             10         146
# Publishing                        7             10         229
# Pulp and paper                    7             10         184
# Real estate                       7             10         178
# Retail                            7             10          86
# Semiconductor                     7             10         148
# Services                          7             10         191
# Shipbuilding                      7             10          88
# Sport                             7             10         190
# Steel                             7             10         190
# Telecommunications                7             10         145
# Textile                           7             10         214
# Transport                         7             10          86
# Video game                        7             10         144
# Water                             7             10          79
#
#                        officePostalCode  jobManagerName  jobManagerId  \
# industry
# Advertising                          94             100           100
# Arms                                 90             100           100
# Automotive                           97              99            99
# Broadcasting                        263             297           297
# Chemical                             92             100           100
# Computer                             90              99            99
# Construction                         95              99            99
# Creative                            183             197           197
# Cultural                            178             199           199
# Culture                             186             200           200
# Defense                             184             200           200
# Education                           272             294           294
# Electric power                      177             198           198
# Electronics                          94              99            99
# Energy                              182             200           200
# Entertainment                       185             197           197
# Fashion                             248             297           297
# Film                                330             395           395
# Financial services                   96             100           100
# Floral                              315             396           396
# Food                                256             294           294
# Information                         261             292           292
# Insurance                            97             100           100
# Internet                             94             100           100
# Leisure                             339             392           392
# Low technology                      263             295           295
# Mass media                          179             199           199
# Meat                                 95              98            98
# Meat packing                         90             100           100
# Mining                               97              99            99
# Music                               333             390           390
# News media                          183             199           199
# Professional services               183             199           199
# Publishing                          336             392           392
# Pulp and paper                      261             295           295
# Real estate                         259             298           298
# Retail                               99              99            99
# Semiconductor                       175             198           198
# Services                            267             297           297
# Shipbuilding                         97             100           100
# Sport                               257             294           294
# Steel                               252             296           296
# Telecommunications                  185             199           199
# Textile                             332             392           392
# Transport                            95             100           100
# Video game                          181             196           196
# Water                                94             100           100
#
#                        totalHours  startDate  endDate  clientName  clientId  \
# industry
# Advertising                    33        100      100           1         1
# Arms                           32        100      100           1         1
# Automotive                     31        100      100           1         1
# Broadcasting                   33        300      300           3         3
# Chemical                       29        100      100           1         1
# Computer                       31        100      100           1         1
# Construction                   31        100      100           1         1
# Creative                       33        200      200           2         2
# Cultural                       33        200      200           2         2
# Culture                        33        200      200           2         2
# Defense                        33        200      200           2         2
# Education                      33        300      300           3         3
# Electric power                 32        200      200           2         2
# Electronics                    31        100      100           1         1
# Energy                         32        200      200           2         2
# Entertainment                  33        200      200           2         2
# Fashion                        33        300      300           3         3
# Film                           33        400      400           4         4
# Financial services             33        100      100           1         1
# Floral                         33        400      400           4         4
# Food                           33        300      300           3         3
# Information                    33        300      299           3         3
# Insurance                      33        100      100           1         1
# Internet                       32        100      100           1         1
# Leisure                        33        400      398           4         4
# Low technology                 33        300      300           3         3
# Mass media                     33        200      200           2         2
# Meat                           32        100      100           1         1
# Meat packing                   32        100      100           1         1
# Mining                         31        100      100           1         1
# Music                          33        400      400           4         4
# News media                     33        200      200           2         2
# Professional services          33        200      200           2         2
# Publishing                     33        400      400           4         4
# Pulp and paper                 33        300      300           3         3
# Real estate                    33        300      300           3         3
# Retail                         32        100      100           1         1
# Semiconductor                  33        200      200           2         2
# Services                       33        300      300           3         3
# Shipbuilding                   32         99      100           1         1
# Sport                          33        300      300           3         3
# Steel                          33        300      300           3         3
# Telecommunications             32        200      200           2         2
# Textile                        33        400      399           4         4
# Transport                      28        100      100           1         1
# Video game                     33        200      200           2         2
# Water                          32        100      100           1         1
#
#                        isUnassigned  requiredSkills.0.name  \
# industry
# Advertising                       2                     11
# Arms                              2                     11
# Automotive                        2                     11
# Broadcasting                      2                     11
# Chemical                          2                     11
# Computer                          2                     11
# Construction                      2                     11
# Creative                          2                     11
# Cultural                          2                     11
# Culture                           2                     11
# Defense                           2                     11
# Education                         2                     11
# Electric power                    2                     11
# Electronics                       2                     11
# Energy                            2                     11
# Entertainment                     2                     11
# Fashion                           2                     11
# Film                              2                     11
# Financial services                2                     11
# Floral                            2                     11
# Food                              2                     11
# Information                       2                     11
# Insurance                         2                     11
# Internet                          2                     11
# Leisure                           2                     11
# Low technology                    2                     11
# Mass media                        2                     11
# Meat                              2                     11
# Meat packing                      2                     11
# Mining                            2                     11
# Music                             2                     11
# News media                        2                     11
# Professional services             2                     11
# Publishing                        2                     11
# Pulp and paper                    2                     11
# Real estate                       2                     11
# Retail                            2                     11
# Semiconductor                     2                     11
# Services                          2                     11
# Shipbuilding                      2                     11
# Sport                             2                     11
# Steel                             2                     11
# Telecommunications                2                     11
# Textile                           2                     11
# Transport                         2                     11
# Video game                        2                     11
# Water                             2                     11
#
#                        requiredSkills.0.category  requiredSkills.1.name  \
# industry
# Advertising                                    2                     11
# Arms                                           2                     10
# Automotive                                     2                     11
# Broadcasting                                   2                     11
# Chemical                                       2                     11
# Computer                                       2                     11
# Construction                                   2                     11
# Creative                                       2                     11
# Cultural                                       2                     11
# Culture                                        2                     11
# Defense                                        2                     11
# Education                                      2                     11
# Electric power                                 2                     11
# Electronics                                    2                     11
# Energy                                         2                     11
# Entertainment                                  2                     11
# Fashion                                        2                     11
# Film                                           2                     11
# Financial services                             2                     11
# Floral                                         2                     11
# Food                                           2                     11
# Information                                    2                     11
# Insurance                                      2                     11
# Internet                                       2                     11
# Leisure                                        2                     11
# Low technology                                 2                     11
# Mass media                                     2                     11
# Meat                                           2                     11
# Meat packing                                   2                     10
# Mining                                         2                     11
# Music                                          2                     11
# News media                                     2                     11
# Professional services                          2                     11
# Publishing                                     2                     11
# Pulp and paper                                 2                     11
# Real estate                                    2                     11
# Retail                                         2                     11
# Semiconductor                                  2                     11
# Services                                       2                     11
# Shipbuilding                                   2                     11
# Sport                                          2                     11
# Steel                                          2                     11
# Telecommunications                             2                     11
# Textile                                        2                     11
# Transport                                      2                     11
# Video game                                     2                     11
# Water                                          2                     10
#
#                        requiredSkills.1.category  requiredSkills.2.name  \
# industry
# Advertising                                    2                     10
# Arms                                           2                     11
# Automotive                                     2                     10
# Broadcasting                                   2                     11
# Chemical                                       2                     11
# Computer                                       2                     10
# Construction                                   2                     10
# Creative                                       2                     11
# Cultural                                       2                     11
# Culture                                        2                     11
# Defense                                        2                     11
# Education                                      2                     11
# Electric power                                 2                     11
# Electronics                                    2                     10
# Energy                                         2                     11
# Entertainment                                  2                     11
# Fashion                                        2                     11
# Film                                           2                     11
# Financial services                             2                     11
# Floral                                         2                     11
# Food                                           2                     11
# Information                                    2                     11
# Insurance                                      2                     10
# Internet                                       2                     11
# Leisure                                        2                     11
# Low technology                                 2                     11
# Mass media                                     2                     11
# Meat                                           2                      9
# Meat packing                                   2                     11
# Mining                                         2                     11
# Music                                          2                     11
# News media                                     2                     11
# Professional services                          2                     11
# Publishing                                     2                     11
# Pulp and paper                                 2                     11
# Real estate                                    2                     11
# Retail                                         2                     10
# Semiconductor                                  2                     11
# Services                                       2                     11
# Shipbuilding                                   2                     10
# Sport                                          2                     11
# Steel                                          2                     11
# Telecommunications                             2                     11
# Textile                                        2                     11
# Transport                                      2                     11
# Video game                                     2                     11
# Water                                          2                     10
#
#                        requiredSkills.2.category  optionalSkills.0.name  \
# industry
# Advertising                                    2                     11
# Arms                                           2                     11
# Automotive                                     2                     11
# Broadcasting                                   2                     11
# Chemical                                       2                     11
# Computer                                       2                     11
# Construction                                   2                     11
# Creative                                       2                     11
# Cultural                                       2                     11
# Culture                                        2                     11
# Defense                                        2                     11
# Education                                      2                     11
# Electric power                                 2                     11
# Electronics                                    2                     11
# Energy                                         2                     11
# Entertainment                                  2                     11
# Fashion                                        2                     11
# Film                                           2                     11
# Financial services                             2                     11
# Floral                                         2                     11
# Food                                           2                     11
# Information                                    2                     11
# Insurance                                      2                     11
# Internet                                       2                     11
# Leisure                                        2                     11
# Low technology                                 2                     11
# Mass media                                     2                     11
# Meat                                           2                     11
# Meat packing                                   2                     11
# Mining                                         2                     11
# Music                                          2                     11
# News media                                     2                     11
# Professional services                          2                     11
# Publishing                                     2                     11
# Pulp and paper                                 2                     11
# Real estate                                    2                     11
# Retail                                         2                     11
# Semiconductor                                  2                     11
# Services                                       2                     11
# Shipbuilding                                   2                     11
# Sport                                          2                     11
# Steel                                          2                     11
# Telecommunications                             2                     11
# Textile                                        2                     11
# Transport                                      2                     11
# Video game                                     2                     11
# Water                                          2                     11
#
#                        optionalSkills.0.category  requiredSkills.3.name  \
# industry
# Advertising                                    2                      7
# Arms                                           2                      8
# Automotive                                     2                     10
# Broadcasting                                   2                     11
# Chemical                                       2                      7
# Computer                                       2                      9
# Construction                                   2                      8
# Creative                                       2                     10
# Cultural                                       2                     11
# Culture                                        2                      9
# Defense                                        2                      9
# Education                                      2                     11
# Electric power                                 2                     11
# Electronics                                    2                     11
# Energy                                         2                     11
# Entertainment                                  2                     11
# Fashion                                        2                     10
# Film                                           2                     11
# Financial services                             2                      9
# Floral                                         2                     11
# Food                                           2                     11
# Information                                    2                     11
# Insurance                                      2                      9
# Internet                                       2                      9
# Leisure                                        2                     11
# Low technology                                 2                     11
# Mass media                                     2                     10
# Meat                                           2                      9
# Meat packing                                   2                      7
# Mining                                         2                      7
# Music                                          2                     11
# News media                                     2                     11
# Professional services                          2                     11
# Publishing                                     2                     11
# Pulp and paper                                 2                     11
# Real estate                                    2                     11
# Retail                                         2                      9
# Semiconductor                                  2                     11
# Services                                       2                     11
# Shipbuilding                                   2                      9
# Sport                                          2                     11
# Steel                                          2                     11
# Telecommunications                             2                     10
# Textile                                        2                     11
# Transport                                      2                      9
# Video game                                     2                     10
# Water                                          2                      7
#
#                        requiredSkills.3.category
# industry
# Advertising                                    2
# Arms                                           2
# Automotive                                     2
# Broadcasting                                   2
# Chemical                                       2
# Computer                                       2
# Construction                                   2
# Creative                                       2
# Cultural                                       2
# Culture                                        2
# Defense                                        2
# Education                                      2
# Electric power                                 2
# Electronics                                    2
# Energy                                         2
# Entertainment                                  2
# Fashion                                        2
# Film                                           2
# Financial services                             2
# Floral                                         2
# Food                                           2
# Information                                    2
# Insurance                                      2
# Internet                                       2
# Leisure                                        2
# Low technology                                 2
# Mass media                                     2
# Meat                                           2
# Meat packing                                   2
# Mining                                         2
# Music                                          2
# News media                                     2
# Professional services                          2
# Publishing                                     2
# Pulp and paper                                 2
# Real estate                                    2
# Retail                                         2
# Semiconductor                                  2
# Services                                       2
# Shipbuilding                                   2
# Sport                                          2
# Steel                                          2
# Telecommunications                             2
# Textile                                        2
# Transport                                      2
# Video game                                     2
# Water                                          2

# %%
f = plt.figure()
f.set_figwidth(15)
plt.ylabel("nb of projects")
df_industry.nunique()['id'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='industry', ylabel='nb of projects'>

# %% [markdown]
# The industries that have the most projects are Film, Textile, Music, Leisure, Floral and Publishing.

# %%
#f = plt.figure()
#f.set_figwidth(15)
#plt.ylabel("nb of projects")
unassigned = {k[0]:v for k, v in df_industry['isUnassigned'].value_counts().items() if k[1] == True}

# %%
f = plt.figure()
f.set_figwidth(15)
plt.xticks(rotation='vertical')
plt.ylabel("number of unassigned projects")
plt.bar(unassigned.keys(), unassigned.values())
# Out:
# <BarContainer object of 47 artists>

# %% [markdown]
# The industries looking for the most talents are the Floral, Leisure and Textile ones. Construction is not looking for many talents.

# %% [markdown]
# ### Investigating office cities

# %%
df_flattened.groupby('officePostalCode').nunique()
# Out:
#                   id  originalId  talentId  talentName  talentGrade  \
# officePostalCode
# 00130              8           8         5           5            2
# 00211              8           8         6           6            5
# 00274              4           4         4           4            3
# 00294             13          13        11          11            7
# 00448              7           7         7           7            5
# ...               ..         ...       ...         ...          ...
# 99428              6           6         4           4            3
# 99682             10          10         9           9            6
# 99689              6           6         6           6            5
# 99749             15          15        12          12            7
# 99833              8           8         8           8            5
#
#                   bookingGrade  operatingUnit  officeCity  jobManagerName  \
# officePostalCode
# 00130                        5              6           8               8
# 00211                        4              6           8               8
# 00274                        2              4           4               4
# 00294                        4              8          13              13
# 00448                        2              4           7               7
# ...                        ...            ...         ...             ...
# 99428                        3              4           6               6
# 99682                        3              6          10              10
# 99689                        2              4           6               6
# 99749                        5              9          14              15
# 99833                        2              6           8               8
#
#                   jobManagerId  totalHours  startDate  endDate  clientName  \
# officePostalCode
# 00130                        8           7          8        8           8
# 00211                        8           7          8        8           7
# 00274                        4           4          4        4           4
# 00294                       13          12         13       13          12
# 00448                        7           5          7        7           7
# ...                        ...         ...        ...      ...         ...
# 99428                        6           6          6        6           6
# 99682                       10           9         10       10          10
# 99689                        6           6          6        6           5
# 99749                       15          12         15       15          14
# 99833                        8           7          8        8           8
#
#                   clientId  industry  isUnassigned  requiredSkills.0.name  \
# officePostalCode
# 00130                    8         8             2                      4
# 00211                    7         6             2                      6
# 00274                    4         4             2                      1
# 00294                   12        12             2                      6
# 00448                    7         7             2                      4
# ...                    ...       ...           ...                    ...
# 99428                    6         6             2                      2
# 99682                   10        10             2                      5
# 99689                    5         5             2                      3
# 99749                   14        13             2                      7
# 99833                    8         7             2                      5
#
#                   requiredSkills.0.category  requiredSkills.1.name  \
# officePostalCode
# 00130                                     2                      4
# 00211                                     2                      2
# 00274                                     1                      1
# 00294                                     2                      5
# 00448                                     2                      2
# ...                                     ...                    ...
# 99428                                     2                      1
# 99682                                     2                      3
# 99689                                     1                      2
# 99749                                     2                      7
# 99833                                     2                      5
#
#                   requiredSkills.1.category  requiredSkills.2.name  \
# officePostalCode
# 00130                                     2                      3
# 00211                                     2                      0
# 00274                                     1                      0
# 00294                                     2                      3
# 00448                                     2                      3
# ...                                     ...                    ...
# 99428                                     1                      1
# 99682                                     2                      2
# 99689                                     1                      3
# 99749                                     2                      3
# 99833                                     2                      3
#
#                   requiredSkills.2.category  optionalSkills.0.name  \
# officePostalCode
# 00130                                     2                      6
# 00211                                     0                      4
# 00274                                     0                      3
# 00294                                     2                      7
# 00448                                     2                      3
# ...                                     ...                    ...
# 99428                                     1                      4
# 99682                                     2                      4
# 99689                                     2                      6
# 99749                                     2                      7
# 99833                                     2                      5
#
#                   optionalSkills.0.category  requiredSkills.3.name  \
# officePostalCode
# 00130                                     2                      1
# 00211                                     2                      0
# 00274                                     2                      0
# 00294                                     2                      2
# 00448                                     2                      2
# ...                                     ...                    ...
# 99428                                     2                      0
# 99682                                     2                      1
# 99689                                     2                      1
# 99749                                     2                      5
# 99833                                     2                      1
#
#                   requiredSkills.3.category
# officePostalCode
# 00130                                     1
# 00211                                     0
# 00274                                     0
# 00294                                     2
# 00448                                     2
# ...                                     ...
# 99428                                     0
# 99682                                     1
# 99689                                     1
# 99749                                     2
# 99833                                     1
#
# [996 rows x 27 columns]

# %%
df_flattened.groupby('officeCity').nunique()
# Out:
#               id  originalId  talentId  talentName  talentGrade  bookingGrade  \
# officeCity
# Ahaus         19          19        15          15            6             6
# Altentreptow  32          32        23          23            7             6
# Altötting     40          40        32          32            7             5
# Angermünde    27          27        23          23            7             4
# Anklam         7           7         5           5            4             4
# ...           ..         ...       ...         ...          ...           ...
# Wunsiedel     17          17        14          14            7             4
# Wurzen        12          12        11          11            6             3
# Zerbst        13          13        11          11            6             3
# Zossen        36          36        27          27            7             6
# Zschopau      18          18        14          14            6             4
#
#               operatingUnit  officePostalCode  jobManagerName  jobManagerId  \
# officeCity
# Ahaus                     9                18              19            19
# Altentreptow             10                32              32            32
# Altötting                10                39              40            40
# Angermünde                9                27              27            27
# Anklam                    5                 7               7             7
# ...                     ...               ...             ...           ...
# Wunsiedel                 9                17              17            17
# Wurzen                    7                12              12            12
# Zerbst                    6                13              13            13
# Zossen                   10                35              36            36
# Zschopau                  8                18              18            18
#
#               totalHours  startDate  endDate  clientName  clientId  industry  \
# officeCity
# Ahaus                 16         19       19          17        17        12
# Altentreptow          24         32       32          31        31        22
# Altötting             23         40       40          32        32        22
# Angermünde            18         27       27          26        26        19
# Anklam                 6          7        7           7         7         7
# ...                  ...        ...      ...         ...       ...       ...
# Wunsiedel             15         17       17          16        16        16
# Wurzen                12         12       12          10        10         9
# Zerbst                11         13       13          11        11        11
# Zossen                19         36       36          31        31        24
# Zschopau              14         18       18          16        16        15
#
#               isUnassigned  requiredSkills.0.name  requiredSkills.0.category  \
# officeCity
# Ahaus                    2                      8                          2
# Altentreptow             2                     11                          2
# Altötting                2                     10                          2
# Angermünde               2                      6                          2
# Anklam                   2                      4                          2
# ...                    ...                    ...                        ...
# Wunsiedel                2                      8                          2
# Wurzen                   2                      7                          2
# Zerbst                   2                      6                          2
# Zossen                   2                     10                          2
# Zschopau                 2                      7                          2
#
#               requiredSkills.1.name  requiredSkills.1.category  \
# officeCity
# Ahaus                             7                          2
# Altentreptow                     10                          2
# Altötting                         8                          2
# Angermünde                        6                          2
# Anklam                            2                          2
# ...                             ...                        ...
# Wunsiedel                         7                          2
# Wurzen                            8                          2
# Zerbst                            5                          2
# Zossen                            9                          2
# Zschopau                          7                          2
#
#               requiredSkills.2.name  requiredSkills.2.category  \
# officeCity
# Ahaus                             5                          2
# Altentreptow                      6                          2
# Altötting                         6                          2
# Angermünde                        5                          2
# Anklam                            2                          1
# ...                             ...                        ...
# Wunsiedel                         6                          2
# Wurzen                            5                          2
# Zerbst                            3                          2
# Zossen                            6                          2
# Zschopau                          6                          2
#
#               optionalSkills.0.name  optionalSkills.0.category  \
# officeCity
# Ahaus                            10                          2
# Altentreptow                     11                          2
# Altötting                        10                          2
# Angermünde                        8                          2
# Anklam                            4                          2
# ...                             ...                        ...
# Wunsiedel                         9                          2
# Wurzen                            6                          2
# Zerbst                            7                          2
# Zossen                            9                          2
# Zschopau                         10                          2
#
#               requiredSkills.3.name  requiredSkills.3.category  grade
# officeCity
# Ahaus                             3                          2      6
# Altentreptow                      3                          1      6
# Altötting                         3                          2      6
# Angermünde                        5                          2      6
# Anklam                            1                          1      5
# ...                             ...                        ...    ...
# Wunsiedel                         6                          2      6
# Wurzen                            4                          2      5
# Zerbst                            1                          1      6
# Zossen                            5                          2      6
# Zschopau                          3                          1      5
#
# [363 rows x 28 columns]

# %% [markdown]
# On a sidenote, an office city can be associated with many office postal codes. For instance, Altötting appears with 39 different postal codes.

# %%
df_flattened['officeCity'].value_counts(ascending=False)[:3]
# Out:
# Stade          101
# Großenhain      78
# Gerolzhofen     76
# Name: officeCity, dtype: int64

# %% [markdown]
# The 3 cities with the most projects are Stade, Großenhain, Gerolzhofen.

# %%
df_flattened['officeCity'].value_counts(ascending=True)[:3]
# Out:
# Gunzenhausen    3
# Calau           4
# Beilngries      5
# Name: officeCity, dtype: int64

# %% [markdown]
# The 3 cities with the least projects are Gunzenhausen, Calau, Beilngries.

# %%
unassignedCities = df_flattened.groupby('officeCity')['isUnassigned'].value_counts()

# %%
unassignedCities
# Out:
# officeCity    isUnassigned
# Ahaus         False           14
#               True             5
# Altentreptow  False           22
#               True            10
# Altötting     False           34
#                               ..
# Zerbst        True             3
# Zossen        False           27
#               True             9
# Zschopau      False           13
#               True             5
# Name: isUnassigned, Length: 715, dtype: int64

# %%
cities = [k[0] for k in unassignedCities.keys()]

# %%
unassignedProjects = [v for k, v in unassignedCities.items() if k[1] == True]

# %%
unassignedProjects, cities = zip(*sorted(zip(unassignedProjects, cities), key=lambda x: x[0]))

# %%
cities[:3]
# Out:
# ('Ansbach', 'Arnstadt', 'Bad Brückenau')

# %% [markdown]
# Ansbach, Arnstadt and Bad Brückenau are among the cities that are looking for the least talents (one).

# %%
cities[-3:]
# Out:
# ('Halberstadt', 'Haldensleben', 'Heiligenstadt')

# %%
unassignedProjects[-3:]
# Out:
# (17, 17, 24)

# %% [markdown]
# Halberstadt, Haldensleben and Heiligenstadt are among the cities that are looking for the most talents (17 and 24).

# %%
df_flattened.groupby('officeCity')['industry'].value_counts(ascending=False)
# Out:
# officeCity  industry
# Ahaus       Fashion         3
#             Floral          3
#             Education       2
#             Food            2
#             Textile         2
#                            ..
# Zschopau    Shipbuilding    1
#             Sport           1
#             Textile         1
#             Video game      1
#             Water           1
# Name: industry, Length: 6700, dtype: int64

# %%
df_flattened.groupby('industry')['officeCity'].value_counts(ascending=False)
# Out:
# industry     officeCity
# Advertising  Erbisdorf      3
#              Stade          3
#              Erfurt         2
#              Gießen         2
#              Großenhain     2
#                            ..
# Water        Wanzleben      1
#              Wernigerode    1
#              Wertingen      1
#              Wiedenbrück    1
#              Zschopau       1
# Name: officeCity, Length: 6700, dtype: int64

# %% [markdown]
# ### Investigating Grades

# %%
df_flattened['grade'] = df_flattened['talentGrade'] + df_flattened['bookingGrade']
df['grade'] = df_flattened['talentGrade'] + df_flattened['bookingGrade']

# %%
df_flattened.groupby('grade')['totalHours'].mean()
# Out:
# grade
# Associate           24.003036
# Intern              23.879037
# Lead Associate      23.899181
# Manager             23.934721
# Senior Associate    24.063604
# Senior Manager      24.466530
# Name: totalHours, dtype: float64

# %% [markdown]
# The grade needed for a project does not depend on the number of hours for this project. Skills don't depend on the grade.

# %%
df_flattened.groupby('grade').nunique()
# Out:
#                     id  originalId  talentId  talentName  talentGrade  \
# grade
# Associate         1647        1647       122         122            2
# Intern            1827        1827       135         135            2
# Lead Associate    1587        1587       110         110            2
# Manager           1777        1777       129         129            2
# Senior Associate  1698        1698       124         124            2
# Senior Manager    1464        1464       104         104            2
#
#                   bookingGrade  operatingUnit  officeCity  officePostalCode  \
# grade
# Associate                    2             10         350               809
# Intern                       2             10         353               833
# Lead Associate               2             10         344               800
# Manager                      2             10         344               844
# Senior Associate             2             10         346               823
# Senior Manager               2             10         339               778
#
#                   jobManagerName  jobManagerId  totalHours  startDate  \
# grade
# Associate                   1517          1517          33       1643
# Intern                      1666          1666          33       1826
# Lead Associate              1467          1467          33       1583
# Manager                     1612          1613          33       1773
# Senior Associate            1547          1547          33       1689
# Senior Manager              1349          1349          33       1461
#
#                   endDate  clientName  clientId  industry  isUnassigned  \
# grade
# Associate            1647         100       100        47             2
# Intern               1823          99        99        47             2
# Lead Associate       1582         100       100        47             2
# Manager              1774          98        98        47             2
# Senior Associate     1695          99        99        47             2
# Senior Manager       1461         100       100        47             2
#
#                   requiredSkills.0.name  requiredSkills.0.category  \
# grade
# Associate                            11                          2
# Intern                               11                          2
# Lead Associate                       11                          2
# Manager                              11                          2
# Senior Associate                     11                          2
# Senior Manager                       11                          2
#
#                   requiredSkills.1.name  requiredSkills.1.category  \
# grade
# Associate                            11                          2
# Intern                               11                          2
# Lead Associate                       11                          2
# Manager                              11                          2
# Senior Associate                     11                          2
# Senior Manager                       11                          2
#
#                   requiredSkills.2.name  requiredSkills.2.category  \
# grade
# Associate                            11                          2
# Intern                               11                          2
# Lead Associate                       11                          2
# Manager                              11                          2
# Senior Associate                     11                          2
# Senior Manager                       11                          2
#
#                   optionalSkills.0.name  optionalSkills.0.category  \
# grade
# Associate                            11                          2
# Intern                               11                          2
# Lead Associate                       11                          2
# Manager                              11                          2
# Senior Associate                     11                          2
# Senior Manager                       11                          2
#
#                   requiredSkills.3.name  requiredSkills.3.category
# grade
# Associate                            11                          2
# Intern                               11                          2
# Lead Associate                       11                          2
# Manager                              11                          2
# Senior Associate                     11                          2
# Senior Manager                       11                          2

# %%
df['numberSkills'] = df['requiredSkills'].apply(len)

# %%
df.groupby('grade')['numberSkills'].mean()
# Out:
# grade
# Associate           1.697632
# Intern              1.689108
# Lead Associate      1.639572
# Manager             1.687113
# Senior Associate    1.619552
# Senior Manager      1.640710
# Name: numberSkills, dtype: float64

# %%
mapping = {'Intern':0,'Associate':1,'Lead Associate':2,'Senior Associate':3,'Manager':4,'Senior Manager':5}

# %%
df['gradeId'] = df['grade'].map(mapping)

# %%
skillsVSGrade = df.groupby('gradeId')['numberSkills'].mean()

# %%
plt.scatter(skillsVSGrade.keys(), skillsVSGrade.values)

# %% [markdown]
# There is no correlation between the number of skills required and the grade for a project.

# %% [markdown]
# # Insights

# %% [markdown]
# A talent (including managers) can work in different operating units and different cities. It would be useful to check if they can work on multiple projects (and in multiple cities) at the same time. A list of talent skills could help to assign a talent with necessary skills on a project.

# %% [markdown]
# An office postal code is linked with multiple office cities in the dataset (investigating office cities).

# %% [markdown]
# No correlation has been found between any set of attributes.
